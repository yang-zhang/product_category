# %% [markdown]
# - https://nijianmo.github.io/amazon/index.html
# - https://jmcauley.ucsd.edu/data/amazon/
# - https://colab.research.google.com/drive/1Zv6MARGQcrBbLHyjPVVMZVnRWsRnVMpV

# %%
prfx = 'prep_20210304A1'

# %% [markdown]
# # get data

# %% [markdown]
#     download from http://localhost:8080/notebooks/git/product-category/notebooks/secrets_get_amazon_data.ipynb

# %%
import pandas as pd
import gzip
import json

# %%
pdata = "/data/git/product-category/data/amazon_meta_data"
# !ls -hl {pdata}
# Out:
# total 13G
# -rw-rw-r-- 1 ubuntu ubuntu   30M Dec  2 00:07 meta_AMAZON_FASHION.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  9.6M Aug  7  2020 meta_All_Beauty.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   57M Aug  7  2020 meta_Appliances.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   57M Aug  7  2020 meta_Appliances.json.gz.1
# -rw-rw-r-- 1 ubuntu ubuntu  125M Aug  7  2020 meta_Arts_Crafts_and_Sewing.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.5G Aug  7  2020 meta_Automotive.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2G Aug  7  2020 meta_Books.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2G Aug  7  2020 meta_Books.json.gz.1
# -rw-rw-r-- 1 ubuntu ubuntu  153M Aug  7  2020 meta_CDs_and_Vinyl.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  333M Aug  7  2020 meta_Cell_Phones_and_Accessories.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.5G Dec  2 00:18 meta_Clothing_Shoes_and_Jewelry.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   12M Aug  7  2020 meta_Digital_Music.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2G Aug  7  2020 meta_Electronics.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  372K Aug  7  2020 meta_Gift_Cards.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  102M Aug  7  2020 meta_Grocery_and_Gourmet_Food.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.7G Aug  7  2020 meta_Home_and_Kitchen.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   79M Aug  7  2020 meta_Industrial_and_Scientific.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   96M Aug  7  2020 meta_Kindle_Store.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  7.1M Aug  7  2020 meta_Luxury_Beauty.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2M Aug  7  2020 meta_Magazine_Subscriptions.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  100M Aug  7  2020 meta_Movies_and_TV.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  163M Aug  7  2020 meta_Musical_Instruments.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  485M Aug  7  2020 meta_Office_Products.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  399M Aug  7  2020 meta_Patio_Lawn_and_Garden.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  269M Aug  7  2020 meta_Pet_Supplies.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  4.9M Aug  7  2020 meta_Prime_Pantry.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   15M Aug  7  2020 meta_Software.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  490M Aug  7  2020 meta_Sports_and_Outdoors.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu 1008M Aug  7  2020 meta_Tools_and_Home_Improvement.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  763M Aug  7  2020 meta_Toys_and_Games.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   50M Aug  7  2020 meta_Video_Games.json.gz

# %%
fnms = !ls {pdata}
fnms = [o for o in fnms if o.endswith('.json.gz')]
fnms
# Out:
# ['meta_AMAZON_FASHION.json.gz',
#  'meta_All_Beauty.json.gz',
#  'meta_Appliances.json.gz',
#  'meta_Arts_Crafts_and_Sewing.json.gz',
#  'meta_Automotive.json.gz',
#  'meta_Books.json.gz',
#  'meta_CDs_and_Vinyl.json.gz',
#  'meta_Cell_Phones_and_Accessories.json.gz',
#  'meta_Clothing_Shoes_and_Jewelry.json.gz',
#  'meta_Digital_Music.json.gz',
#  'meta_Electronics.json.gz',
#  'meta_Gift_Cards.json.gz',
#  'meta_Grocery_and_Gourmet_Food.json.gz',
#  'meta_Home_and_Kitchen.json.gz',
#  'meta_Industrial_and_Scientific.json.gz',
#  'meta_Kindle_Store.json.gz',
#  'meta_Luxury_Beauty.json.gz',
#  'meta_Magazine_Subscriptions.json.gz',
#  'meta_Movies_and_TV.json.gz',
#  'meta_Musical_Instruments.json.gz',
#  'meta_Office_Products.json.gz',
#  'meta_Patio_Lawn_and_Garden.json.gz',
#  'meta_Pet_Supplies.json.gz',
#  'meta_Prime_Pantry.json.gz',
#  'meta_Software.json.gz',
#  'meta_Sports_and_Outdoors.json.gz',
#  'meta_Tools_and_Home_Improvement.json.gz',
#  'meta_Toys_and_Games.json.gz',
#  'meta_Video_Games.json.gz']

# %%
domains = [o.strip('meta_').strip('.json.gz') for o in fnms]
dmn2fnm = dict(zip(domains, fnms))
dmn2fnm
# Out:
# total 13G
# -rw-rw-r-- 1 ubuntu ubuntu   30M Dec  2 00:07 meta_AMAZON_FASHION.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  9.6M Aug  7  2020 meta_All_Beauty.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   57M Aug  7  2020 meta_Appliances.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   57M Aug  7  2020 meta_Appliances.json.gz.1
# -rw-rw-r-- 1 ubuntu ubuntu  125M Aug  7  2020 meta_Arts_Crafts_and_Sewing.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.5G Aug  7  2020 meta_Automotive.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2G Aug  7  2020 meta_Books.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2G Aug  7  2020 meta_Books.json.gz.1
# -rw-rw-r-- 1 ubuntu ubuntu  153M Aug  7  2020 meta_CDs_and_Vinyl.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  333M Aug  7  2020 meta_Cell_Phones_and_Accessories.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.5G Dec  2 00:18 meta_Clothing_Shoes_and_Jewelry.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   12M Aug  7  2020 meta_Digital_Music.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2G Aug  7  2020 meta_Electronics.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  372K Aug  7  2020 meta_Gift_Cards.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  102M Aug  7  2020 meta_Grocery_and_Gourmet_Food.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.7G Aug  7  2020 meta_Home_and_Kitchen.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   79M Aug  7  2020 meta_Industrial_and_Scientific.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   96M Aug  7  2020 meta_Kindle_Store.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  7.1M Aug  7  2020 meta_Luxury_Beauty.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2M Aug  7  2020 meta_Magazine_Subscriptions.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  100M Aug  7  2020 meta_Movies_and_TV.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  163M Aug  7  2020 meta_Musical_Instruments.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  485M Aug  7  2020 meta_Office_Products.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  399M Aug  7  2020 meta_Patio_Lawn_and_Garden.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  269M Aug  7  2020 meta_Pet_Supplies.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  4.9M Aug  7  2020 meta_Prime_Pantry.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   15M Aug  7  2020 meta_Software.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  490M Aug  7  2020 meta_Sports_and_Outdoors.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu 1008M Aug  7  2020 meta_Tools_and_Home_Improvement.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  763M Aug  7  2020 meta_Toys_and_Games.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   50M Aug  7  2020 meta_Video_Games.json.gz
# {'AMAZON_FASHION': 'meta_AMAZON_FASHION.json.gz',
#  'All_Beauty': 'meta_All_Beauty.json.gz',
#  'Appliance': 'meta_Appliances.json.gz',
#  'Arts_Crafts_and_Sewi': 'meta_Arts_Crafts_and_Sewing.json.gz',
#  'Automotive': 'meta_Automotive.json.gz',
#  'Book': 'meta_Books.json.gz',
#  'CDs_and_Vinyl': 'meta_CDs_and_Vinyl.json.gz',
#  'Cell_Phones_and_Accessorie': 'meta_Cell_Phones_and_Accessories.json.gz',
#  'Clothing_Shoes_and_Jewelry': 'meta_Clothing_Shoes_and_Jewelry.json.gz',
#  'Digital_Music': 'meta_Digital_Music.json.gz',
#  'Electronic': 'meta_Electronics.json.gz',
#  'Gift_Card': 'meta_Gift_Cards.json.gz',
#  'Grocery_and_Gourmet_Food': 'meta_Grocery_and_Gourmet_Food.json.gz',
#  'Home_and_Kitche': 'meta_Home_and_Kitchen.json.gz',
#  'Industrial_and_Scientific': 'meta_Industrial_and_Scientific.json.gz',
#  'Kindle_Store': 'meta_Kindle_Store.json.gz',
#  'Luxury_Beauty': 'meta_Luxury_Beauty.json.gz',
#  'Magazine_Subscripti': 'meta_Magazine_Subscriptions.json.gz',
#  'Movies_and_TV': 'meta_Movies_and_TV.json.gz',
#  'Musical_Instrument': 'meta_Musical_Instruments.json.gz',
#  'Office_Product': 'meta_Office_Products.json.gz',
#  'Patio_Lawn_and_Garde': 'meta_Patio_Lawn_and_Garden.json.gz',
#  'Pet_Supplie': 'meta_Pet_Supplies.json.gz',
#  'Prime_Pantry': 'meta_Prime_Pantry.json.gz',
#  'Software': 'meta_Software.json.gz',
#  'Sports_and_Outdoor': 'meta_Sports_and_Outdoors.json.gz',
#  'Tools_and_Home_Improvement': 'meta_Tools_and_Home_Improvement.json.gz',
#  'Toys_and_Game': 'meta_Toys_and_Games.json.gz',
#  'Video_Game': 'meta_Video_Games.json.gz'}

# %%
KEYS2USE = set(['category', 'description', 'title', 'brand', 'feature', 'asin'])

# %%
# https://colab.research.google.com/drive/1Zv6MARGQcrBbLHyjPVVMZVnRWsRnVMpV#scrollTo=7igYuRaV4bF7
    
### load the meta data
def get_meta_data(domain, nrows=None):
    keys2use = KEYS2USE
    fnm = dmn2fnm[domain]
    data = []
    with gzip.open(f'{pdata}/{fnm}') as f:
        for i,l in enumerate(f):
            dat = json.loads(l.strip())
            dat = {k:v for k,v in dat.items() if k in keys2use}
            data.append(dat)
            if nrows and i>nrows: break

    # total length of list, this number equals total number of products
#     print("len(data)", len(data))

    # convert list into pandas dataframe
    df = pd.DataFrame.from_dict(data)
#     print("len(df)", len(df))

    ### remove rows with unformatted title (i.e. some 'title' may still contain html style content)
    df3 = df.fillna('')
    df4 = df3[df3.title.str.contains('getTime')] # unformatted rows
    df5 = df3[~df3.title.str.contains('getTime')] # filter those unformatted rows
#     print("len(df4)", len(df4))
#     print("len(df5)", len(df5))

    return df5

# %%
df = get_meta_data(domains[3], nrows=10000)
df.head(3)
# Out:
#                                             category  \
# 0  [Arts, Crafts & Sewing, Sewing, Trim & Embelli...
# 1  [Arts, Crafts & Sewing, Crafting, Paper & Pape...
# 2  [Arts, Crafts & Sewing, Painting, Drawing & Ar...
#
#                                          description  \
# 0  [The patch features the sweaty masculine hands...
# 1  [With 5 packs stars folding paper, each pack a...
# 2                                                 []
#
#                                                title          brand  \
# 0         You Son of a Bitch! 1987 Embroidered Patch      Honchosfx
# 1          Origami Stars Papers Package 1H (5 packs)
# 2  Yi De Ge Chinese Calligraphy Sumi Drawing Blac...  MasterChinese
#
#                                              feature        asin
# 0  [You son of a bitch patch - exclusive to Honch...  6665560953
# 1                                                 []  7000000376
# 2                                                 []  7000001089

# %% [raw]
# for dmn in domains:
#     df = get_meta_data(dmn, nrows=1000)
#     print(dmn, df.shape)
#     display(df.sample(5))

# %% [markdown]
# # preprocess data

# %% [markdown]
# ## concate

# %%
dfs = []
for dmn in domains:
    print(dmn)
    df = get_meta_data(dmn, nrows=None)
    if set(df.columns)!= KEYS2USE: continue
    df = df[df.category.apply(len)>0]
    if len(df)==0: continue
    print(df.shape)
    df['domain'] = dmn
    display(df.sample(2))
    dfs.append(df)
# Out:
# AMAZON_FASHION
# All_Beauty
# Appliance
# (29639, 6)
#                                                 category  \
# 14385  [Appliances, Parts & Accessories, Refrigerator...
# 10273  [Appliances, Parts & Accessories, Refrigerator...
#
#                                              description  \
# 14385  [CB10942 for GE WR55X10942 Refrigerator Defros...
# 10273  [This blower wheel will replace a worn or dama...
#
#                                                    title      brand  \
# 14385  Refrigerator Main Control Board for Ge Wr55x10...         GE
# 10273                     Whirlpool 53-0106 Blower Wheel  Whirlpool
#
#                                                  feature        asin  \
# 14385  [Brand New! Refrigerator Control Board. Replac...  B00EYLZB78
# 10273  [Manufactured to fit a 1/2-Inch motor shaft, C...  B00A8O07ME
#
#           domain
# 14385  Appliance
# 10273  Appliance
# Arts_Crafts_and_Sewi
# (284889, 6)
#                                                  category  \
# 30301   [Arts, Crafts & Sewing, Painting, Drawing & Ar...
# 162949  [Arts, Crafts & Sewing, Knitting & Crochet, Kn...
#
#                                               description  \
# 30301   [Art Advantage mini easel oil paint set. Set c...
# 162949  [Ultra Sponge Bar (Needle Retainer) Strip for ...
#
#                                                     title  \
# 30301              Art Advantage Mini Easel Oil Paint Set
# 162949  NEW Adhesive Back Sponge for Brother/Singer/St...
#
#                          brand  \
# 30301            Art Advantage
# 162949  Ultra Sponge Bar Strip
#
#                                                   feature        asin  \
# 30301   [Oil paint set, Comes with a table easel, One ...  B0027A39CC
# 162949  [Made in the USA, Fits standard & bulky gauge ...  B00INHVJ34
#
#                       domain
# 30301   Arts_Crafts_and_Sewi
# 162949  Arts_Crafts_and_Sewi
# Automotive
# (897587, 6)
#                                                  category  \
# 422771                    [Automotive, Tools & Equipment]
# 785230  [Automotive, Motorcycle & Powersports, Protect...
#
#                                               description  \
# 422771  [Dorman is a leading supplier of original equi...
# 785230  [The Viking Cycle Warlock Motorcycle Mesh Jack...
#
#                                                    title         brand  \
# 422771  Dorman 49051 Multi Use Removal Tool Set, 5 Piece        Dorman
# 785230            Viking Cycle Motorcycle Jacket for Men  Viking Cycle
#
#                                                   feature        asin  \
# 422771  [Kit includes a wide edge remover, narrow edge...  B008ZCGZUY
# 785230  [Hand wash, Cooling mesh shell that covers; to...  B00Y1Q3U92
#
#             domain
# 422771  Automotive
# 785230  Automotive
# Book
# (2545520, 6)
#                                                   category  \
# 2423185        [Books, Literature &amp; Fiction, Literary]
# 831689   [Books, Crafts, Hobbies &amp; Home, Antiques &...
#
#                                                description  \
# 2423185  [J.S. Scott is a New York Times and USA Today ...
# 831689           [Text: English, German (translation), , ]
#
#                                                      title  \
# 2423185  Billionaire Undone: The Billionaire's Obsessio...
# 831689   The History of Modern Furniture (English and G...
#
#                                    brand feature        asin domain
# 2423185  Visit Amazon's J. S. Scott Page      []  193996248X   Book
# 831689     Visit Amazon's Karl Mang Page      []  0810910667   Book
# CDs_and_Vinyl
# (516914, 6)
#                                        category  \
# 7907    [CDs & Vinyl, Classical, Chamber Music]
# 483059                 [CDs & Vinyl, Classical]
#
#                                               description  \
# 7907       [LASZLO KOVACS - BEST OF OPERETTA VOL. 2 - CD]
# 483059  [Following the rebirth of the Erato label in 2...
#
#                                                     title            brand  \
# 7907                         Best of Operetta 2 / Various  VARIOUS ARTISTS
# 483059  Beethoven : Piano Sonatas No.7, No.14, 'Moonli...  Nicola Lugansky
#
#        feature        asin         domain
# 7907        []  B0000014CG  CDs_and_Vinyl
# 483059      []  B00I5OZ1VG  CDs_and_Vinyl
# Cell_Phones_and_Accessorie
# (534466, 6)
#                                                  category  \
# 206353  [Cell Phones & Accessories, Cases, Holsters & ...
# 563567  [Cell Phones & Accessories, Cases, Holsters & ...
#
#                                               description  \
# 206353                                                 []
# 563567  [<b>xhorizon Premium Leather Folio Case [Walle...
#
#                                                     title       brand  \
# 206353  HTC Desire 601 British Blue Police Box Phone C...  TrekCovers
# 563567  Case for Samsung S7 Edge,xhorizon TM FL8 Premi...    xhorizon
#
#                                                   feature        asin  \
# 206353                                                 []  B00GG1J3AA
# 563567  [Details of the wallet case cover:100% brand n...  B01EY0OOD0
#
#                             domain
# 206353  Cell_Phones_and_Accessorie
# 563567  Cell_Phones_and_Accessorie
# Clothing_Shoes_and_Jewelry
# (2665580, 6)
#                                                   category  \
# 2160464  [Clothing, Shoes & Jewelry, Women, Shoes, Slip...
# 2397006  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
#
#                                                description  \
# 2160464  [Toggle Trim Full Collar Slipper. Extra Comfor...
# 2397006  [Very soft and breathable thong made from micr...
#
#                                                      title     brand  \
# 2160464  Sleepers Womens/Ladies Tanya Toggle Trim Full ...  Sleepers
# 2397006        Emporio Armani Men's Basic Microfiber Thong
#
#                                                    feature        asin  \
# 2160464  [Mixed, ,, Toggle Trim Full Collar Slipper., E...  B015GNAJJW
# 2397006  [Package Dimensions:\n                    \n19...  B01AY1WK34
#
#                              domain
# 2160464  Clothing_Shoes_and_Jewelry
# 2397006  Clothing_Shoes_and_Jewelry
# Digital_Music
# (7, 6)
#                                     category  \
# 59077                  [Digital Music, Folk]
# 70842  [Digital Music, Broadway & Vocalists]
#
#                                              description  \
# 59077                                                 []
# 70842  [The age of vaudeville. A quartet of penguins ...
#
#                                                    title            brand  \
# 59077                                           Uncorked       Al Stewart
# 70842  <span id="parentalAdvisory" class="a-size-medi...  Various artists
#
#       feature        asin         domain
# 59077      []  B00B7U613C  Digital_Music
# 70842      []  B01433U8MY  Digital_Music
# Electronic
# (786445, 6)
#                                                  category  \
# 231686  [Electronics, Computers & Accessories, Laptop ...
# 127139  [Electronics, Computers & Accessories, Compute...
#
#                                               description  \
# 231686  [Compatible 6-Cell Dell PP39L Battery rated at...
# 127139                                  [Office Keyboard]
#
#                                 title         brand  \
# 231686  Compatible Dell PP39L Battery  BatteryNerds
# 127139     IVR63200 - Office Keyboard      Innovera
#
#                                                   feature        asin  \
# 231686                                                 []  B0050DU1M4
# 127139  [Batteries Included - No, Batteries Required -...  B0016T3P10
#
#             domain
# 231686  Electronic
# 127139  Electronic
# Gift_Card
# (1542, 6)
#                                               category  \
# 995                           [Gift Cards, Gift Cards]
# 944  [Gift Cards, Gift Cards, No expiration, no fee...
#
#                                            description  \
# 995  [Buca di Beppo is the perfect place for great ...
# 944                                                 []
#
#                                                  title brand feature  \
# 995         Buca di Beppo Gift Cards - E-mail Delivery            []
# 944   Amazon Gift Card - Print - Feliz Cumplea&ntil...            []
#
#            asin     domain
# 995  B00MV9EWRU  Gift_Card
# 944  B00JQKK1PE  Gift_Card
# Grocery_and_Gourmet_Food
# (287051, 6)
#                                                  category  \
# 76625   [Grocery & Gourmet Food, Beverages, Coffee, Te...
# 154854        [Grocery & Gourmet Food, Candy & Chocolate]
#
#                                               description  \
# 76625   [Twinings Of London Pure Peppermint Herbal Tea...
# 154854  [Si usted tiene alguna pregunta, yo hablo espa...
#
#                                                     title     brand feature  \
# 76625   Twinings of London Pure Peppermint Tea K-Cups ...  Twinings      []
# 154854  2 X Sanborns Agua De Colonia Clasica Flor De N...  Sanborns      []
#
#               asin                    domain
# 76625   B004LL7EZS  Grocery_and_Gourmet_Food
# 154854  B00DXO0QSG  Grocery_and_Gourmet_Food
# Home_and_Kitche
# (1300540, 6)
#                                                  category  \
# 213966  [Home & Kitchen, Kitchen & Dining, Bakeware, C...
# 968012  [Home & Kitchen, Kitchen & Dining, Kitchen Ute...
#
#                                               description  \
# 213966  [CK Products chocolate molds are first quality...
# 968012  [CafePress brings your passions to life with t...
#
#                                                     title        brand  \
# 213966  CK Products -5/8-Inch Letters/Numbers Chocolat...  CK Products
# 968012  CafePress Scottish Terrier - Obey the Scottie!...    CafePress
#
#                                                   feature        asin  \
# 213966  [Each piece is -5/8-inch by 1/2-inch by 1/8-in...  B003QP36A2
# 968012  [Express yourself with a rectangle magnet desi...  B00VN9PYZI
#
#                  domain
# 213966  Home_and_Kitche
# 968012  Home_and_Kitche
# Industrial_and_Scientific
# (159350, 6)
#                                                 category  \
# 59429  [Industrial & Scientific, Hydraulics, Pneumati...
# 43115  [Industrial & Scientific, Science Education, S...
#
#                                              description  \
# 59429  [<div class=aplus>, This Ideal-Tridon Turn-Key...
# 43115  [<div class="aplus">, The American Educational...
#
#                                                    title  \
# 59429  Ideal-Tridon Turn-Key Series Stainless Steel 2...
# 43115  American Educational 15 Piece Fluorescent Mine...
#
#                                brand feature        asin  \
# 59429                   Ideal-Tridon      []  B008Z64HQO
# 43115  American Educational Products      []  B005QDPT1G
#
#                           domain
# 59429  Industrial_and_Scientific
# 43115  Industrial_and_Scientific
# Kindle_Store
# (491670, 6)
#                                                  category description  \
# 333475  [Kindle Store, Kindle eBooks, Literature & Fic...          []
# 192532             [Kindle Store, Kindle eBooks, History]          []
#
#                                                     title            brand  \
# 333475  The Complete History of the Penis - Kindle edi...  Adoni Patrikios
# 192532           Lafayette is Here! (Kindle Single) eBook      John Baxter
#
#        feature        asin        domain
# 333475      []  B00R6LYK7U  Kindle_Store
# 192532      []  B00EQ2EGSK  Kindle_Store
# Luxury_Beauty
# Magazine_Subscripti
# (2883, 6)
#                                                category  \
# 1897  [Magazine Subscriptions, Technology, Computers...
# 1449  [Magazine Subscriptions, Professional & Educat...
#
#                                             description  \
# 1897  [Published since 1994, <I>PC Pro</I> is a Brit...
# 1449  [Intended as continuing education, IFR Refresh...
#
#                                               title  \
# 1897  <span class="a-size-medium a-color-secondary"
# 1449  <span class="a-size-medium a-color-secondary"
#
#                                brand feature        asin               domain
# 1897  Dennis Publ Ltd/Cust Intreface      []  B00007J7UC  Magazine_Subscripti
# 1449               Belvoir Publs Inc      []  B00006KHRK  Magazine_Subscripti
# Movies_and_TV
# (203541, 6)
#                                                  category  \
# 115636  [Movies & TV, Boxed Sets, Art House & Internat...
# 188711                     [Movies & TV, Blu-ray, Movies]
#
#                                               description  \
# 115636  [Luis "Huicho" Dominguez is a poor, low class,...
# 188711  [When Mafuyu Oribe and her adopted sister Tomo...
#
#                                           title           brand feature  \
# 115636                          El Premio Mayor    Sergio Goyri      []
# 188711  Qwaser of Stigmata: Complete Collection  Ayumi Fujimura      []
#
#               asin         domain
# 115636  B001BEK8II  Movies_and_TV
# 188711  B00NW6KPXQ  Movies_and_TV
# Musical_Instrument
# (114397, 6)
#                                                 category  \
# 57071  [Musical Instruments, Amplifiers & Effects, Gu...
# 34079  [Musical Instruments, Instrument Accessories, ...
#
#                                              description  \
# 57071                                   [Guitar Booster]
# 34079  [Featured in the worlds top selling 4x12 cabin...
#
#                                                    title              brand  \
# 57071  T-Rex Engineering Crunchy Frog Classic Overdri...  T-Rex Engineering
# 34079            Celestion G12T-75 Guitar Speaker, 8 Ohm          CELESTION
#
#                                                  feature        asin  \
# 57071                                                 []  B0064ROWNO
# 34079  [Built to meet the demands of todays high gain...  B001LOOYP6
#
#                    domain
# 57071  Musical_Instrument
# 34079  Musical_Instrument
# Office_Product
# (298876, 6)
#                                                  category  \
# 78459   [Office Products, Office & School Supplies, Wr...
# 101108  [Office Products, Office & School Supplies, De...
#
#                                               description  \
# 78459   [Staedtler Mechanical Pencil Night Blue Series...
# 101108  [This 8" round mousepad of the image shown is ...
#
#                                                     title      brand  \
# 78459   Staedtler Mechanical Pencil Night Blue Series,...  Staedtler
# 101108   Titanic Round Mousepad Mouse Pad Great Gift Idea     MYDply
#
#                                                   feature        asin  \
# 78459   [Staedtler Mechanical Pencil for Draft, Night ...  B003LOQ790
# 101108  [Round Mouse Pad (8"), Great gift item. Imprin...  B005DFH7JY
#
#                 domain
# 78459   Office_Product
# 101108  Office_Product
# Patio_Lawn_and_Garde
# (279456, 6)
#                                                  category  \
# 224112  [Patio, Lawn & Garden, Gardening & Lawn Care, ...
# 160793  [Patio, Lawn & Garden, Snow Removal, Snow Shov...
#
#                                               description  \
# 224112  [The Melnor 300 Oscillating Sprinkler With Bra...
# 160793  [10", Deluxe ice chopper/scraper, tempered gal...
#
#                                                     title    brand  \
# 224112  Melnor 300 Oscillating Sprinkler With Brass No...   Melnor
# 160793       SUNCAST SSD9500 10&quot;DLX Ice Chop/Scraper  Suncast
#
#                                                   feature        asin  \
# 224112  [Durable brass jets provide excellent water di...  B010NYVR04
# 160793  [This are Putty knives, This are highly durabl...  B00IOX69YG
#
#                       domain
# 224112  Patio_Lawn_and_Garde
# 160793  Patio_Lawn_and_Garde
# Pet_Supplie
# (189454, 6)
#                                                  category  \
# 73753               [Pet Supplies, Dogs, Toys, Chew Toys]
# 115565  [Pet Supplies, Dogs, Apparel & Accessories, Ba...
#
#                                               description  \
# 73753   [JW Pet Company Tough By Nature Bad Cuz Large ...
# 115565  [Celebrate Christmas with this scarf bandana. ...
#
#                                                     title       brand  \
# 73753   JW Pet Company Tough By Nature Bad Cuz Large D...      JW Pet
# 115565  I See Spot Merry Christmas Dog Pet Bandana Sca...  I See Spot
#
#                                                   feature        asin  \
# 73753                  [Sale JW Pet Company, Rubber Toys]  B00629UDE6
# 115565  [Merry Christmas Holiday bandana, Made of soft...  B00FRRYYLW
#
#              domain
# 73753   Pet_Supplie
# 115565  Pet_Supplie
# Prime_Pantry
# Software
# (24727, 6)
#                                            category  \
# 23529  [Software, Education & Reference, Languages]
# 3423                        [Software, Photography]
#
#                                              description  \
# 23529  [Tell Me More v10.5 German 10 Levels will allo...
# 3423   [98/W2K/WME/XP, Ulead PhotoImpact 8 delivers t...
#
#                                          title          brand feature  \
# 23529  Rosetta Stone Tell Me More German v10.5       Mongoora      []
# 3423                             PhotoImpact 8  ULead Systems      []
#
#              asin    domain
# 23529  B00JPVF88E  Software
# 3423   B000068D9B  Software
# Sports_and_Outdoor
# (893979, 6)
#                                                  category  \
# 154156  [Sports & Outdoors, Sports & Fitness, Team Spo...
# 646388  [Sports & Outdoors, Outdoor Recreation, Water ...
#
#                                               description  \
# 154156  [Crew neck with long sleeve construction. Bio-...
# 646388  [BIC SUP's new TRACER series ("Touring-Racer")...
#
#                                               title      brand  \
# 154156          Easton Short Sleeve Enforcer Jacket     Easton
# 646388  BIC Sport C-TEC Tracer Stand up Paddleboard  BIC Sport
#
#                                                   feature        asin  \
# 154156  [Lightweight Batting Shell, Full Range Motion ...  B0032V8WYK
# 646388  [TRACER series ("Touring-Racer") excels as bot...  B00NGDGQ4W
#
#                     domain
# 154156  Sports_and_Outdoor
# 646388  Sports_and_Outdoor
# Tools_and_Home_Improvement
# (544118, 6)
#                                                  category  \
# 568111  [Tools & Home Improvement, Electrical, Electri...
# 82079   [Tools & Home Improvement, Paint, Wall Treatme...
#
#                                               description  \
# 568111  [<b>* TOOGOO is a registered trademark. ONLY A...
# 82079   [Interior/Exterior American Accents Aerosol Pa...
#
#                                                     title       brand  \
# 568111  6300-23000RPM DC Motor - TOOGOO(R)6300-23000RP...   TOOGOO(R)
# 82079   Rust-Oleum 7931830 American Accents Spray, Sat...  Rust-Oleum
#
#                                                   feature        asin  \
# 568111  [Product Name : DC Motor, Rated Voltage : DC 3...  B01H01ODFO
# 82079   [Smooth satin finish, Can be used outdoors or ...  B0010OKMZ8
#
#                             domain
# 568111  Tools_and_Home_Improvement
# 82079   Tools_and_Home_Improvement
# Toys_and_Game
# (571640, 6)
#                                                category  \
# 373585  [Toys & Games, Kids' Furniture, Dcor & Storage]
# 519521   [Toys & Games, Baby & Toddler Toys, Bath Toys]
#
#                                               description  \
# 373585  [Try a new spin on the "rocking horse" with th...
# 519521  [This listing is for a DC Comics Rubber Duck d...
#
#                                                     title      brand  \
# 373585  Qaba Kids Plush Rocking Horse-Style Elephant T...       Qaba
# 519521  Dc Comics Superman Rubber Duck with Flashing L...  DC Comics
#
#                                                   feature        asin  \
# 373585  [Comfortably rocks back and forth, Durable lig...  B00GM1KJLG
# 519521  [Rubber Duck Dressed as Superman, When pushed ...  B00Z36LL5Y
#
#                domain
# 373585  Toys_and_Game
# 519521  Toys_and_Game
# Video_Game
# (82394, 6)
#                                                 category  \
# 19483  [Video Games, Retro Gaming & Microconsoles, Pl...
# 79545                         [Video Games, Accessories]
#
#                                              description  \
# 19483  [<I>Dance Dance Revolution: Disney Mix</I> get...
# 79545  [1.support: iOS, Android, Windows &amp; Mac OS...
#
#                                                    title   brand  \
# 19483                 Dance Dance Revolution: Disney Mix  Konami
# 79545  8bitdo F30 Pro Wireless Bluetooth Controller D...  8Bitdo
#
#                                                  feature        asin  \
# 19483                                                 []  B00005NCAA
# 79545  [FC30 Pro is a bluetooth/USB gamepad professio...  B018K3Q4JY
#
#            domain
# 19483  Video_Game
# 79545  Video_Game

# %%
df = pd.concat(dfs)
df.shape
# Out:
# (13706665, 7)

# %%
df.sample(3)
# Out:
#                                                  category  \
# 38560   [Kindle Store, Kindle eBooks, Health, Fitness ...
# 477817  [Kindle Store, Kindle eBooks, Science Fiction ...
# 238857  [Electronics, Computers & Accessories, Compute...
#
#                                               description  \
# 38560                                                  []
# 477817                                                 []
# 238857  [Specifications:<br>\n-Supports SuperSpeed USB...
#
#                                                     title  \
# 38560   9 Diet Secrets To Help Women Lose Weight - Kin...
# 477817                              Echoes from Yesterday
# 238857  Koutech EEU330 3.5&quot; SuperSpeed USB 3.0 Ex...
#
#                                     brand  \
# 38560                       Sarah Benning
# 477817  Visit Amazon's Sean Benjamin Page
# 238857                            Koutech
#
#                                                   feature        asin  \
# 38560                                                  []  B005C5Z4PY
# 477817                                                 []  B01F2LQEVU
# 238857  [Supports transfer rate at 12Mbps (Full-Speed ...  B00570NYJW
#
#               domain
# 38560   Kindle_Store
# 477817  Kindle_Store
# 238857    Electronic

# %% [markdown]
# ## cleanup

# %% [markdown]
# ### category

# %%
# %%time
def try2eval(x):
    try:
        x = eval(x)
        x = (o.replace('|','') for o in x)
        return '|'.join(x)
    except SyntaxError:
        return ""

df.category = df.category.astype(str)
df.category = df.category.apply(try2eval)
print("df.shape:", df.shape)
# Out:
# df.shape: (13706665, 7)
# CPU times: user 3min 23s, sys: 5.56 s, total: 3min 28s
# Wall time: 3min 29s

# %% [markdown]
# ### text

# %%
import re

def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

# %%
# %%time
df.fillna('', inplace=True)

for col in ['description', 'feature']:
    df[col] = df[col].apply(lambda x: "\n".join(x) if len(x) else "")

for col in ['description', 'title', 'brand', 'feature',]:
    df[col] = df[col].apply(cleanhtml)
# Out:
# CPU times: user 3min 15s, sys: 4.7 s, total: 3min 20s
# Wall time: 3min 20s

# %%
# %%time
df['txt'] = df.title + " " + df.brand + " " + df.description + " " + df.feature
# Out:
# CPU times: user 28.2 s, sys: 8.71 s, total: 36.9 s
# Wall time: 36.8 s

# %% [markdown]
# # train val split

# %%
import numpy as np

np.random.seed(101)
df['is_validation'] = np.random.choice(2, size=len(df), p=[0.85,0.15])

# %%
df.is_validation.value_counts()
# Out:
# 0    11649852
# 1     2056813
# Name: is_validation, dtype: int64

# %%
df.sample(3)
# Out:
#                                                   category  \
# 173884   CDs & Vinyl|Alternative Rock|New Wave & Post-P...
# 1251629  Clothing, Shoes & Jewelry|Women|Shoes|Boots|Kn...
# 934399   Clothing, Shoes & Jewelry|Women|Contemporary &...
#
#                                                description  \
# 173884   VARIOUS ARTISTS - 1980S: MODERN ROCK OF THE 80...
# 1251629  The Aquatalia by Marvin K. collection is manuf...
# 934399   Enjoy all-star footwear from one of the most r...
#
#                                          title            brand  \
# 173884   Hardest Hits: Modern Rock of the 80's  Various Artists
# 1251629    Aquatalia Women's Helena Dress Boot        Aquatalia
# 934399   kate spade new york Women's Cris Pump
#
#                                                    feature        asin  \
# 173884                                                      B00009PXXA
# 1251629  100% Leather\nImported\nSynthetic sole\nShaft ...  B00ISSXHZG
# 934399   100% Leather\nImported\nLeather sole\nHeel mea...  B00DSLK594
#
#                              domain  \
# 173884                CDs_and_Vinyl
# 1251629  Clothing_Shoes_and_Jewelry
# 934399   Clothing_Shoes_and_Jewelry
#
#                                                        txt  is_validation
# 173884   Hardest Hits: Modern Rock of the 80's Various ...              0
# 1251629  Aquatalia Women's Helena Dress Boot Aquatalia ...              0
# 934399   kate spade new york Women's Cris Pump  Enjoy a...              0

# %% [markdown]
# # save

# %%
# %%time
df.to_csv(f'../data/data__{prfx}.csv', index=False)
# Out:
# CPU times: user 8min 18s, sys: 29.9 s, total: 8min 48s
# Wall time: 8min 49s

# %%
ls -hl ../data/data__{prfx}.csv
# Out:
# -rw-rw-r-- 1 ubuntu ubuntu 22G Mar  5 02:23 ../data/data__prep_20210304A1.csv

# %% [markdown]
# ## make a sample

# %%
import numpy as np
np.random.seed(101)
df_sample = df.sample(10000)

# %%
df_sample.to_csv(f'../data/data_sample__{prfx}.csv', index=False)

# %% [markdown]
# ## make more samples

# %%
# %%time
df = pd.read_csv(f'../data/data__{prfx}.csv')
# Out:
# <string>:2: DtypeWarning: Columns (1,2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
# CPU times: user 3min 4s, sys: 24.5 s, total: 3min 28s
# Wall time: 4min 57s

# %%
len(df)
# Out:
# (14688205, 9)

# %%
for sz in (int(o) for o in (1e4, 1e5, 1e6, 5e6)):
    df_sample = df.sample(sz)
    df_sample.to_csv(f'../data/data_sample_{sz}__{prfx}.csv', index=False)

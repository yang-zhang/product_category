# %% [markdown]
# - https://nijianmo.github.io/amazon/index.html
# - https://jmcauley.ucsd.edu/data/amazon/
# - https://colab.research.google.com/drive/1Zv6MARGQcrBbLHyjPVVMZVnRWsRnVMpV

# %% [markdown]
# # get data

# %% [markdown]
#     download from http://localhost:8080/notebooks/git/product-category/notebooks/secrets_get_amazon_data.ipynb

# %%
import pandas as pd
import gzip
import json

# %%
pdata = "/data/git/product-category/data/amazon_meta_data"
# !ls -hl {pdata}
fnms = !ls {pdata}
fnms = [o for o in fnms if o.endswith('.json.gz')]
domains = [o.strip('meta_').strip('.json.gz') for o in fnms]
dmn2fnm = dict(zip(domains, fnms))
dmn2fnm
# Out:
# total 13G
# -rw-rw-r-- 1 ubuntu ubuntu   30M Dec  2 00:07 meta_AMAZON_FASHION.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  9.6M Aug  7  2020 meta_All_Beauty.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   57M Aug  7  2020 meta_Appliances.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   57M Aug  7  2020 meta_Appliances.json.gz.1
# -rw-rw-r-- 1 ubuntu ubuntu  125M Aug  7  2020 meta_Arts_Crafts_and_Sewing.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.5G Aug  7  2020 meta_Automotive.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2G Aug  7  2020 meta_Books.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2G Aug  7  2020 meta_Books.json.gz.1
# -rw-rw-r-- 1 ubuntu ubuntu  153M Aug  7  2020 meta_CDs_and_Vinyl.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  333M Aug  7  2020 meta_Cell_Phones_and_Accessories.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.5G Dec  2 00:18 meta_Clothing_Shoes_and_Jewelry.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   12M Aug  7  2020 meta_Digital_Music.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2G Aug  7  2020 meta_Electronics.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  372K Aug  7  2020 meta_Gift_Cards.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  102M Aug  7  2020 meta_Grocery_and_Gourmet_Food.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.7G Aug  7  2020 meta_Home_and_Kitchen.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   79M Aug  7  2020 meta_Industrial_and_Scientific.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   96M Aug  7  2020 meta_Kindle_Store.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  7.1M Aug  7  2020 meta_Luxury_Beauty.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  1.2M Aug  7  2020 meta_Magazine_Subscriptions.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  100M Aug  7  2020 meta_Movies_and_TV.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  163M Aug  7  2020 meta_Musical_Instruments.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  485M Aug  7  2020 meta_Office_Products.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  399M Aug  7  2020 meta_Patio_Lawn_and_Garden.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  269M Aug  7  2020 meta_Pet_Supplies.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  4.9M Aug  7  2020 meta_Prime_Pantry.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   15M Aug  7  2020 meta_Software.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  490M Aug  7  2020 meta_Sports_and_Outdoors.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu 1008M Aug  7  2020 meta_Tools_and_Home_Improvement.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu  763M Aug  7  2020 meta_Toys_and_Games.json.gz
# -rw-rw-r-- 1 ubuntu ubuntu   50M Aug  7  2020 meta_Video_Games.json.gz
# {'AMAZON_FASHION': 'meta_AMAZON_FASHION.json.gz',
#  'All_Beauty': 'meta_All_Beauty.json.gz',
#  'Appliance': 'meta_Appliances.json.gz',
#  'Arts_Crafts_and_Sewi': 'meta_Arts_Crafts_and_Sewing.json.gz',
#  'Automotive': 'meta_Automotive.json.gz',
#  'Book': 'meta_Books.json.gz',
#  'CDs_and_Vinyl': 'meta_CDs_and_Vinyl.json.gz',
#  'Cell_Phones_and_Accessorie': 'meta_Cell_Phones_and_Accessories.json.gz',
#  'Clothing_Shoes_and_Jewelry': 'meta_Clothing_Shoes_and_Jewelry.json.gz',
#  'Digital_Music': 'meta_Digital_Music.json.gz',
#  'Electronic': 'meta_Electronics.json.gz',
#  'Gift_Card': 'meta_Gift_Cards.json.gz',
#  'Grocery_and_Gourmet_Food': 'meta_Grocery_and_Gourmet_Food.json.gz',
#  'Home_and_Kitche': 'meta_Home_and_Kitchen.json.gz',
#  'Industrial_and_Scientific': 'meta_Industrial_and_Scientific.json.gz',
#  'Kindle_Store': 'meta_Kindle_Store.json.gz',
#  'Luxury_Beauty': 'meta_Luxury_Beauty.json.gz',
#  'Magazine_Subscripti': 'meta_Magazine_Subscriptions.json.gz',
#  'Movies_and_TV': 'meta_Movies_and_TV.json.gz',
#  'Musical_Instrument': 'meta_Musical_Instruments.json.gz',
#  'Office_Product': 'meta_Office_Products.json.gz',
#  'Patio_Lawn_and_Garde': 'meta_Patio_Lawn_and_Garden.json.gz',
#  'Pet_Supplie': 'meta_Pet_Supplies.json.gz',
#  'Prime_Pantry': 'meta_Prime_Pantry.json.gz',
#  'Software': 'meta_Software.json.gz',
#  'Sports_and_Outdoor': 'meta_Sports_and_Outdoors.json.gz',
#  'Tools_and_Home_Improvement': 'meta_Tools_and_Home_Improvement.json.gz',
#  'Toys_and_Game': 'meta_Toys_and_Games.json.gz',
#  'Video_Game': 'meta_Video_Games.json.gz'}

# %%
KEYS2USE = set(['category', 'description', 'title', 'brand', 'feature', 'asin'])

# %%
# https://colab.research.google.com/drive/1Zv6MARGQcrBbLHyjPVVMZVnRWsRnVMpV#scrollTo=7igYuRaV4bF7
    
### load the meta data
def get_meta_data(domain, nrows=None):
    keys2use = KEYS2USE
    fnm = dmn2fnm[domain]
    data = []
    with gzip.open(f'{pdata}/{fnm}') as f:
        for i,l in enumerate(f):
            dat = json.loads(l.strip())
            dat = {k:v for k,v in dat.items() if k in keys2use}
            data.append(dat)
            if nrows and i>nrows: break

    # total length of list, this number equals total number of products
#     print("len(data)", len(data))

    # convert list into pandas dataframe
    df = pd.DataFrame.from_dict(data)
#     print("len(df)", len(df))

    ### remove rows with unformatted title (i.e. some 'title' may still contain html style content)
    df3 = df.fillna('')
    df4 = df3[df3.title.str.contains('getTime')] # unformatted rows
    df5 = df3[~df3.title.str.contains('getTime')] # filter those unformatted rows
#     print("len(df4)", len(df4))
#     print("len(df5)", len(df5))

    return df5

# %%
df = get_meta_data(domains[3], nrows=10000)
df.head(3)
# Out:
#                                             category  \
# 0  [Arts, Crafts & Sewing, Sewing, Trim & Embelli...
# 1  [Arts, Crafts & Sewing, Crafting, Paper & Pape...
# 2  [Arts, Crafts & Sewing, Painting, Drawing & Ar...
#
#                                          description  \
# 0  [The patch features the sweaty masculine hands...
# 1  [With 5 packs stars folding paper, each pack a...
# 2                                                 []
#
#                                                title          brand  \
# 0         You Son of a Bitch! 1987 Embroidered Patch      Honchosfx
# 1          Origami Stars Papers Package 1H (5 packs)
# 2  Yi De Ge Chinese Calligraphy Sumi Drawing Blac...  MasterChinese
#
#                                              feature        asin
# 0  [You son of a bitch patch - exclusive to Honch...  6665560953
# 1                                                 []  7000000376
# 2                                                 []  7000001089

# %% [raw]
# for dmn in domains:
#     df = get_meta_data(dmn, nrows=1000)
#     print(dmn, df.shape)
#     display(df.sample(5))

# %% [markdown]
# # preprocess data

# %%
dfs = []
for dmn in domains:
    df = get_meta_data(dmn, nrows=1000)
    if set(df.columns)!= KEYS2USE: continue
    df = df[df.category.apply(len)>0]
    if len(df)==0: continue
    print(dmn, df.shape)
    df['domain'] = dmn
    display(df.sample(2))
    dfs.append(df)
# Out:
# Appliance (989, 6)
#                                               category  \
# 854  [Appliances, Parts &amp; Accessories, Refriger...
# 422  [Appliances, Parts & Accessories, Food Waste D...
#
#                                            description  \
# 854  [, <br /><strong>Replace Every Six Months</str...
# 422  [The EZ-FLO garbage disposer splash guard is d...
#
#                                                  title        brand  \
# 854  ALPINEWATER 4396841, 4396710, Kenmore 9030, 90...  ALPINEWATER
# 422         EZ-FLO 30102 Garbage Disposer Splash Guard       EZ-Flo
#
#                                                feature        asin     domain
# 854  [The real filter life span depends on water qu...  B000GJYMJK  Appliance
# 422          [Splash guard, Fits *insinkerator, Black]  B00068UTY8  Appliance
# Arts_Crafts_and_Sewi (971, 6)
#                                               category  \
# 812  [Arts, Crafts & Sewing, Sewing, Sewing Notions...
# 831  [Arts, Crafts & Sewing, Crafting, Paper & Pape...
#
#                                            description  \
# 812  [Ideal for carrying bulky items! Heavy duty fu...
# 831  [Express your creativity! Create announcements...
#
#                                                  title         brand  \
# 812  VELCRO Brand All-Purpose Strap with Handle | L...  VELCRO Brand
# 831  Geographics Design Paper, Scroll, 24 lb, 8.5 x...   Geographics
#
#                                                feature        asin  \
# 812  [NOTICE: Amazon is a trusted seller of Velcro ...  B00006IC2S
# 831  [Express your creativity!, Create announcement...  B00006IDX0
#
#                    domain
# 812  Arts_Crafts_and_Sewi
# 831  Arts_Crafts_and_Sewi
# Automotive (945, 6)
#                                               category  \
# 528     [Automotive, Exterior Accessories, Body Armor]
# 116  [Automotive, Exterior Accessories, Bumper Stic...
#
#                                            description  \
# 528                                                 []
# 116  [If it doesn't have a Flag It header - its an ...
#
#                                                  title    brand  \
# 528         Megaman X Ultimate Armor Kit - Force Armor
# 116  Flag It California Heavy Duty Vinyl Bumper Sti...  Flag It
#
#                                                feature        asin      domain
# 528                                                 []  B00009WNYB  Automotive
# 116  [Great for windows, cars, travel trailers, boa...  9539751322  Automotive
# Book (842, 6)
#                                             category description  \
# 253                        [Books, Children's Books]          []
# 257  [Books, Literature & Fiction, World Literature]          []
#
#                           title                             brand feature  \
# 253            Has Winter Come?  Visit Amazon's Wendy Watson Page      []
# 257  VANCOUVER A Novel (Signed)  David & Griffiths, Alison Cruise      []
#
#            asin domain
# 253  0001953184   Book
# 257  0002006588   Book
# CDs_and_Vinyl (1002, 6)
#                                               category  \
# 23                  [CDs & Vinyl, New Age, Meditation]
# 364  [CDs & Vinyl, Rock, Progressive, Progressive R...
#
#                                            description  \
# 23   [Meditation for Success by Michael Midkiff ena...
# 364                                     [Yes Spin-Off]
#
#                                                  title            brand  \
# 23   <span class="a-size-medium a-color-secondary a...  Michael Midkiff
# 364          Anderson, Bruford, Wakeman &amp; Howe VHS
#
#     feature        asin         domain
# 23       []  0615205399  CDs_and_Vinyl
# 364      []  630154224X  CDs_and_Vinyl
# Cell_Phones_and_Accessorie (978, 6)
#                                               category description  \
# 470  [Cell Phones & Accessories, Cases, Holsters & ...          []
# 581  [Cell Phones & Accessories, Accessories, Acces...          []
#
#                                                  title brand feature  \
# 470  3 Items Combo For Nokia Lumia 822 (Verizon) Bl...            []
# 581  Motorola Electrify M XT901 (US Cellular) Color...            []
#
#            asin                      domain
# 470  9862165677  Cell_Phones_and_Accessorie
# 581  9868874505  Cell_Phones_and_Accessorie
# Clothing_Shoes_and_Jewelry (1002, 6)
#                                               category  \
# 940  [Clothing, Shoes & Jewelry, Women, Jewelry, Ri...
# 227  [Clothing, Shoes & Jewelry, Men, Clothing, Shi...
#
#                                            description  \
# 940  [This fabulous channel-set diamond ring is sub...
# 227  [Pour some martinis, put on your favorite jazz...
#
#                                                  title              brand  \
# 940  14k White Gold Channel-set Princess Cut Diamon...  Amazon Collection
# 227            Tommy Bahama Geo-Tastic Silk Camp Shirt
#
#                                                feature        asin  \
# 940  [All our diamond suppliers confirm that they c...  B0000CEMGJ
# 227  [Clothing, Shoes & Jewelry, Men, Clothing, Shi...  9789898282
#
#                          domain
# 940  Clothing_Shoes_and_Jewelry
# 227  Clothing_Shoes_and_Jewelry
# Electronic (1002, 6)
#                                               category  \
# 99   [Electronics, eBook Readers & Accessories, Cov...
# 310  [Electronics, Computers &amp; Accessories, Tab...
#
#                                            description  \
# 99                                                  []
# 310  [PREMIUM USB Adapter Power Kit for Acer Iconia...
#
#                                                  title           brand  \
# 99   NOOK HD 7&quot; Cover - Lautner Cover (Dark Fu...            Nook
# 310  PREMIUM USB Adapter Power Kit for Acer Iconia ...  Factory Direct
#
#                                                feature        asin      domain
# 99                                                  []  0594513189  Electronic
# 310  [This all in one accessory kit includes everyt...  1060119811  Electronic
# Gift_Card (997, 6)
#                                               category description  \
# 840  [Gift Cards, Gift Cards, No expiration, no fee...          []
# 396                           [Gift Cards, Gift Cards]          []
#
#                                                  title brand  \
# 840   Amazon eGift Card - Cake It (Animated) [Hallm...
# 396                                  Amazon eGift Card
#
#                                                feature        asin     domain
# 840  [<span class="a-size-base a-color-secondary">\...  B00H5BM5VE  Gift_Card
# 396                                                 []  B00BWDHT62  Gift_Card
# Grocery_and_Gourmet_Food (1002, 6)
#                                               category  \
# 93   [Grocery & Gourmet Food, Breakfast Foods, Brea...
# 486    [Grocery & Gourmet Food, Meat & Seafood, Bacon]
#
#                                            description  \
# 93   [ZonePerfect Nutrition Bars, Fudge Graham/Choc...
# 486  [Pancetta is a traditional Italian specialty, ...
#
#                                                  title             brand  \
# 93   ZonePerfect Nutrition Bars, Fudge Graham/Choco...      Zone Perfect
# 486                     Pancetta by Beretta (14 ounce)  Fratelli Beretta
#
#     feature        asin                    domain
# 93       []  B0000AA8UL  Grocery_and_Gourmet_Food
# 486      []  B0000D9NCI  Grocery_and_Gourmet_Food
# Home_and_Kitche (1002, 6)
#                                               category  \
# 42   [Home & Kitchen, Bedding, Bed Pillows & Positi...
# 928  [Home & Kitchen, Kitchen & Dining, Bakeware, P...
#
#                                            description  \
# 42   [We don't know when or if this item will be ba...
# 928  [Heavy-gauge steel crisper is perfect for crea...
#
#                                                  title             brand  \
# 42   My Sticker Book: Princess Swing &ndash; Reusab...         Five Star
# 928          Chicago Metallic Commercial Pizza Crisper  Chicago Metallic
#
#                                                feature        asin  \
# 42   [We don't know when or if this item will be ba...  0983124248
# 928  [Perfect for frozen, leftover, or homemade piz...  B00004R91W
#
#               domain
# 42   Home_and_Kitche
# 928  Home_and_Kitche
# Industrial_and_Scientific (981, 6)
#                                               category  \
# 430  [Industrial & Scientific, Tapes, Adhesives & S...
# 779  [Industrial & Scientific, Material Handling Pr...
#
#                                            description  \
# 430  [3M 198 Scotch 1" x 36" Reflective Tape, White...
# 779  [Tough molded rubber wheel and heavy steel mou...
#
#                                                  title    brand  \
# 430  3M 198 Scotch 1&quot; x 36&quot; Reflective Ta...       3M
# 779  Steelex D2622 2-Inch 65-Pound Swivel Rubber Pl...  Steelex
#
#                                                feature        asin  \
# 430  [3M #198 1x40 Silver Grey Refle Tape, 3M COMPANY]  B00004Z49Q
# 779  [2-Inch size, 2-3/8-Inch by 2-Inch plate, Swiv...  B0000DD1FC
#
#                         domain
# 430  Industrial_and_Scientific
# 779  Industrial_and_Scientific
# Kindle_Store (1002, 6)
#                                               category description title  \
# 643  [Kindle Store, Kindle eBooks, Health, Fitness ...          []
# 304  [Kindle Store, Kindle eBooks, Literature &amp;...          []
#
#                                    brand feature        asin        domain
# 643  Visit Amazon's Sylvia K. Blood Page      []  B000OI18EA  Kindle_Store
# 304                  Public Domain Books      []  B000JMKWAW  Kindle_Store
# Magazine_Subscripti (946, 6)
#                                               category  \
# 771  [Magazine Subscriptions, Children & Teen, Chil...
# 512  [Magazine Subscriptions, Sports, Recreation & ...
#
#                                            description  \
# 771  [Magazine for girls of ages 6-12 filled with e...
# 512  [Contains information of interest to individua...
#
#                                              title  \
# 771  <span class="a-size-medium a-color-secondary"
# 512  <span class="a-size-medium a-color-secondary"
#
#                            brand feature        asin               domain
# 771  Bluffton News Publishing Co      []  B00007AXWU  Magazine_Subscripti
# 512        Harris Publishing Inc      []  B00006KX8R  Magazine_Subscripti
# Movies_and_TV (1002, 6)
#                                               category  \
# 281  [Movies & TV, Studio Specials, Sony Pictures H...
# 692  [Movies & TV, Studio Specials, MGM Home Entert...
#
#                                            description  \
# 281  [Monty Python And The Holy Grail, Could this b...
# 692  [Hot stars James Marsden ("Bella Mafia"), Kati...
#
#                                title           brand feature        asin  \
# 281  Monty Python and the Holy Grail  Graham Chapman      []  0767824571
# 692          Disturbing Behavior VHS   James Marsden      []  0792840119
#
#             domain
# 281  Movies_and_TV
# 692  Movies_and_TV
# Musical_Instrument (952, 6)
#                                               category  \
# 182  [Musical Instruments, Studio Recording Equipme...
# 96   [Musical Instruments, Amplifiers & Effects, Gu...
#
#                                            description  \
# 182                                                 []
# 96   [Pedal is green in color. Maximum effect contr...
#
#                       title                brand  \
# 182       MixMan DJ Megamix  Mixman Technologies
# 96   Boss Ph-2 Super Phaser                 BOSS
#
#                                                feature        asin  \
# 182  [Easily create professional quality music on y...  B00004VWIF
# 96   [UPC of this product is G60172171098. It is ba...  1925542475
#
#                  domain
# 182  Musical_Instrument
# 96   Musical_Instrument
# Office_Product (940, 6)
#                                               category  \
# 719  [Office Products, Office &amp; School Supplies...
# 80   [Office Products, Office &amp; School Supplies...
#
#                                          description  \
# 719                                               []
# 80   [Reproducible pages on the back of each chart!]
#
#                                                  title  \
# 719  2012 Switched on Schoolhouse French 1 Elective...
# 80   Scholastic Ocean Adventure! Incentive Chart (T...
#
#                         brand  \
# 719  Alpha Omega Publications
# 80                 Scholastic
#
#                                                feature        asin  \
# 719                                                 []  0740327003
# 80   [Measures 17" x 22"., Plastic-coated for color...  0439505747
#
#              domain
# 719  Office_Product
# 80   Office_Product
# Patio_Lawn_and_Garde (1002, 6)
#                                               category  \
# 959        [Patio, Lawn & Garden, Pest Control, Traps]
# 48   [Patio, Lawn & Garden, Outdoor Dcor, Garden Sc...
#
#                                            description  \
# 959  [RIGID PLASTIC; NON-TIPPING WITH 2 CLAMPS\, Th...
# 48                                                  []
#
#                                                  title           brand  \
# 959                                LINT TRAP W/VINYL -         Unknown
# 48   Japanese Koinobori Koi Nobori NYLON Blue Carp ...  Yokohama Gifts
#
#                                                feature        asin  \
# 959  ["PROFLEX" INDOOR DRYER VENT KIT, 4"x5', White...  B00004YWK5
# 48   [This listing is for 1 Set of Japanese Koinobo...  9622447279
#
#                    domain
# 959  Patio_Lawn_and_Garde
# 48   Patio_Lawn_and_Garde
# Pet_Supplie (939, 6)
#                                               category  \
# 688  [Pet Supplies, Dogs, Treats, Cookies, Biscuits...
# 529                [Pet Supplies, Small Animals, Food]
#
#                                            description  \
# 688  [<b>?Why do you need anti-bark collar StopWoof...
# 529  [Your guinea pig or rabbit wont be able to res...
#
#                                                  title                brand  \
# 688  [NEW 2019] Humane Bark collar-Dog bark Collar-...               Purina
# 529                            Oxbow Orchard Grass Hay  Oxbow Animal Health
#
#                                                feature        asin  \
# 688  [?  EFFECTIVE:  Studies show that 80-85% of do...  B0000BXJG1
# 529                                                 []  B00008DFPK
#
#           domain
# 688  Pet_Supplie
# 529  Pet_Supplie
# Software (776, 6)
#                                               category  \
# 528   [Software, Education &amp; Reference, Languages]
# 702  [Software, Education & Reference, Test Prepara...
#
#                                            description  \
# 528  [This used set includes 1 available French Lev...
# 702  [Affordable, current, and complete study guide...
#
#                                                  title                brand  \
# 528  Rosetta Stone Homeschool French Level 1-3 Set ...        Rosetta Stone
# 702  Essentials of Nursing Care Health Safety, N104...  MyStudyGroup101 LLC
#
#                                                feature        asin    domain
# 528  [Interactive software; Parent's guide; Supplem...  1607179342  Software
# 702                                                 []  1936452006  Software
# Sports_and_Outdoor (916, 6)
#                                               category  \
# 219  [Sports & Outdoors, Fan Shop, Cell Phone Acces...
# 350  [Sports & Outdoors, Outdoor Recreation, Cyclin...
#
#                                            description  \
# 219  [Protect and personalize your Verizon Samsung ...
# 350  [U-Lock Padlocks Keyed Sports Series 8-1/4-inc...
#
#                                                  title            brand  \
# 219  Black Spade Skull Poker Card Design Rubberized...  Handheldfashion
# 350  Master Lock 8184DSG U-Lock with Bracket, 8-1/4...      Master Lock
#
#                                                feature        asin  \
# 219  [High Quality Super Clear LCD Screen Protector...  9861051139
# 350  [8-1/4-inch (21cm) wide steel lock body for st...  B00004SQMD
#
#                  domain
# 219  Sports_and_Outdoor
# 350  Sports_and_Outdoor
# Tools_and_Home_Improvement (951, 6)
#                                               category  \
# 900  [Tools & Home Improvement, Power & Hand Tools,...
# 606  [Tools & Home Improvement, Power & Hand Tools,...
#
#                                            description  \
# 900  [Precision Miter Box With Saw - PRECISION MITE...
# 606                                                 []
#
#                                                  title                brand  \
# 900                Jorgensen 64016 Precision Miter Saw  Adjustable Clamp Co
# 606  Bosch 1275DVS 3-Inch x 24-Inch Variable Speed ...                Bosch
#
#                                                feature        asin  \
# 900  [Miter saw for use in various carpentry projec...  B00002244D
# 606  [10.5 Amps, 1,150 SFPM power for professional ...  B0000223H8
#
#                          domain
# 900  Tools_and_Home_Improvement
# 606  Tools_and_Home_Improvement
# Toys_and_Game (870, 6)
#                                               category  \
# 590  [Toys & Games, Learning & Education, Reading &...
# 277                  [Toys & Games, Games, Card Games]
#
#                                            description  \
# 590  [<b>After</b> your children play with this awe...
# 277                                                 []
#
#                                                  title  \
# 590  Magnetic Before and After Activity Game - Supe...
# 277              Duh: It Will Make You Feel Smart Game
#
#                         brand  \
# 590  Super Duper Publications
# 277                       n/a
#
#                                                feature        asin  \
# 590  [Sturdy, Colorful, Magnetic Game Board (14" x ...  1586503839
# 277                                                 []  0974889148
#
#             domain
# 590  Toys_and_Game
# 277  Toys_and_Game
# Video_Game (982, 6)
#                                               category  \
# 125                                  [Video Games, PC]
# 345  [Video Games, Retro Gaming & Microconsoles, Ni...
#
#                                            description  \
# 125  [The Limited Edition game features six special...
# 345  [Nintendo 64, <i>Star Wars: Episode 1 Racer</i...
#
#                                          title  \
# 125  Battlefield Bad Company 2 Limited Edition
# 345              Star Wars - Episode I - Racer
#
#                                          brand               feature  \
# 125  Battlefield Bad Company 2 Limited Edition                    []
# 345                                   Nintendo  [lose. not with box]
#
#            asin      domain
# 125  8990289440  Video_Game
# 345  B00000J2OO  Video_Game

# %%
df = pd.concat(dfs)

df.shape
# Out:
# (22991, 7)

# %%
df.sample(3)
# Out:
#                                               category  \
# 185  [Industrial & Scientific, Tapes, Adhesives & S...
# 868  [Office Products, Office &amp; School Supplies...
# 491  [Grocery & Gourmet Food, Olives, Pickles & Rel...
#
#                                            description  \
# 185  [America's #1 selling latex caulk. ALEXPLUS is...
# 868  [This Lang Heart &amp; Home 2016 Wall Calendar...
# 491  [This is an authentic German sauerkraut and is...
#
#                                                  title        brand  \
# 185  DAP INC 18152 10.1oz White Alex Plus Acrylic L...          DAP
# 868  The Lang Heart &amp; Home 2016 Wall Calendar f...         Lang
# 491  Kuehne former Gundelsheim Barrel Sauerkraut (1...  Gundelsheim
#
#                                                feature        asin  \
# 185  [Sturdy and secure construction, Perfect for y...  B00002ND6L
# 868  [Artwork from hand painted originals, Brass gr...  0741255162
# 491                                                 []  B0000D9MT2
#
#                         domain
# 185  Industrial_and_Scientific
# 868             Office_Product
# 491   Grocery_and_Gourmet_Food
